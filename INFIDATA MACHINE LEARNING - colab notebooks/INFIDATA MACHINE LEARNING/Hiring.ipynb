# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-efd26e9c-f185-4754-ba4a-0f2ce0da73fc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-efd26e9c-f185-4754-ba4a-0f2ce0da73fc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hiring.csv to hiring.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['hiring.csv']))
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.drop('experience',axis='columns',inplace=True)

# %%
df['test_score(out of 10)']= df['test_score(out of 10)'].fillna(df['test_score(out of 10)'].median())
df
# Out:
#    test_score(out of 10)  interview_score(out of 10)  salary($)
# 0                    8.0                           9      50000
# 1                    8.0                           6      45000
# 2                    6.0                           7      60000
# 3                   10.0                          10      65000
# 4                    9.0                           6      70000
# 5                    7.0                          10      62000
# 6                    8.0                           7      72000
# 7                    7.0                           8      80000

# %%
df.rename(columns={'salary($)':'salary'},inplace=True)
df
# Out:
#    test_score(out of 10)  interview_score(out of 10)  salary
# 0                    8.0                           9   50000
# 1                    8.0                           6   45000
# 2                    6.0                           7   60000
# 3                   10.0                          10   65000
# 4                    9.0                           6   70000
# 5                    7.0                          10   62000
# 6                    8.0                           7   72000
# 7                    7.0                           8   80000

# %%
reg=linear_model.LinearRegression()
reg.fit(df.drop('salary',axis='columns'),df.salary)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.coef_
# Out:
# array([ 47.08798017, 260.22304833])

# %%
reg.intercept_
# Out:
# 60579.92565055762

# %%
reg.predict([[9.0,6]])
# Out:
# array([62565.05576208])

# %%
reg.predict([[10.0,10]])
# Out:
# array([63653.03593556])
