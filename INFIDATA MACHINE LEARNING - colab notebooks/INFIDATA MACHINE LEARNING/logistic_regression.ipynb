# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fb9261e1-a121-459c-8823-82d8f07e5749" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb9261e1-a121-459c-8823-82d8f07e5749">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving insurance_data.csv to insurance_data.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['insurance_data.csv']))
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
X = df.drop('bought_insurance',axis='columns')
y = df['bought_insurance']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
X_train
# Out:
#     age
# 13   29
# 21   26
# 17   58
# 6    55
# 14   49
# 20   21
# 2    47
# 12   27
# 15   55
# 8    62
# 23   45
# 4    46
# 9    61
# 25   54
# 7    60
# 11   28
# 16   25
# 5    56

# %%
X_test
# Out:
#     age
# 3    52
# 22   40
# 0    22
# 26   23
# 1    25
# 10   18
# 19   18
# 18   19
# 24   50

# %%
y_train
# Out:
# 13    0
# 21    0
# 17    1
# 6     0
# 14    1
# 20    0
# 2     1
# 12    0
# 15    1
# 8     1
# 23    1
# 4     1
# 9     1
# 25    1
# 7     1
# 11    0
# 16    1
# 5     1
# Name: bought_insurance, dtype: int64

# %%
y_test
# Out:
# 3     0
# 22    1
# 0     0
# 26    0
# 1     0
# 10    0
# 19    0
# 18    0
# 24    1
# Name: bought_insurance, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
clf.predict(X_test)
# Out:
# array([1, 1, 0, 0, 0, 0, 0, 0, 1])

# %%
y_test
# Out:
# 3     0
# 22    1
# 0     0
# 26    0
# 1     0
# 10    0
# 19    0
# 18    0
# 24    1
# Name: bought_insurance, dtype: int64

# %%
clf.score(X_test,y_test)
# Out:
# 0.8888888888888888

# %%
plt.scatter(X,y)
