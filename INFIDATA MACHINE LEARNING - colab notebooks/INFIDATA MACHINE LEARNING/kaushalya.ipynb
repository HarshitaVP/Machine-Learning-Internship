# %%
import requests 
from bs4 import BeautifulSoup 
import csv

# %%
URL = "https://www.kaushalya.tech/allCourse.html"
r = requests.get(URL)

# %%
soup = BeautifulSoup(r.content, 'html5lib')

# %%
soup.title
# Out:
# <title>All Courses - Best Computer Training Center in Bengaluru|Bangalore|Python|Java|C|C++|ML|AI|Test Automation|IoT|Selenium|Web Development|MEAN|Full Stack</title>

# %%
soup.find(attrs={'class':'panel-body'}).h3
# Out:
# <h3>Web Development</h3>

# %%
soup.find(attrs={'class':'panel-body'}).p
# Out:
# <p>Develop web applications/web sites using HTML/ CSS/ JavaScript/ JQuery/ BootStrap/PHP/MySQL.<br/><br/><strong> Duration: 60 Hrs</strong></p>
