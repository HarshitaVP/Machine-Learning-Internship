# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-aad25f04-87c2-4973-a04b-4e6825040fd7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aad25f04-87c2-4973-a04b-4e6825040fd7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 50_Startups.csv - 50_Startups.csv.csv to 50_Startups.csv - 50_Startups.csv.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['50_Startups.csv - 50_Startups.csv.csv']))
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
X = df.drop(['State','Profit'],axis='columns')
y=df['Profit']

# %%
X
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0   165349.20       136897.80        471784.10
# 1   162597.70       151377.59        443898.53
# 2   153441.51       101145.55        407934.54
# 3   144372.41       118671.85        383199.62
# 4   142107.34        91391.77        366168.42
# 5   131876.90        99814.71        362861.36
# 6   134615.46       147198.87        127716.82
# 7   130298.13       145530.06        323876.68
# 8   120542.52       148718.95        311613.29
# 9   123334.88       108679.17        304981.62
# 10  101913.08       110594.11        229160.95
# 11  100671.96        91790.61        249744.55
# 12   93863.75       127320.38        249839.44
# 13   91992.39       135495.07        252664.93
# 14  119943.24       156547.42        256512.92
# 15  114523.61       122616.84        261776.23
# 16   78013.11       121597.55        264346.06
# 17   94657.16       145077.58        282574.31
# 18   91749.16       114175.79        294919.57
# ...

# %%
y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
clf.score(X,y)
# Out:
# 0.9507459940683246

# %%
clf.coef_
# Out:
# array([ 0.80571505, -0.02681597,  0.02722806])

# %%
clf.intercept_
# Out:
# 50122.19298986523

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
X_train
# Out:
#     R&D Spend  Administration  Marketing Spend
# 3   144372.41       118671.85        383199.62
# 26   75328.87       144135.98        134050.07
# 20   76253.86       113867.30        298664.47
# 5   131876.90        99814.71        362861.36
# 22   73994.56       122782.75        303319.26
# 29   65605.48       153032.06        107138.38
# 23   67532.53       105751.03        304768.73
# 4   142107.34        91391.77        366168.42
# 42   23640.93        96189.63        148001.11
# 36   28663.76       127056.21        201126.82
# 30   61994.48       115641.28         91131.24
# 10  101913.08       110594.11        229160.95
# 21   78389.47       153773.43        299737.29
# 31   61136.38       152701.92         88218.23
# 16   78013.11       121597.55        264346.06
# 24   77044.01        99281.34        140574.81
# 39   38558.51        82982.09        174999.30
# 0   165349.20       136897.80        471784.10
# 27   72107.60       127864.55        353183.81
# ...

# %%
X_test
# Out:
#     R&D Spend  Administration  Marketing Spend
# 6   134615.46       147198.87        127716.82
# 43   15505.73       127382.30         35534.17
# 9   123334.88       108679.17        304981.62
# 40   28754.33       118546.05        172795.67
# 28   66051.52       182645.56        118148.20
# 18   91749.16       114175.79        294919.57
# 11  100671.96        91790.61        249744.55
# 33   55493.95       103057.49        214634.81
# 13   91992.39       135495.07        252664.93
# 17   94657.16       145077.58        282574.31
# 19   86419.70       153514.11             0.00
# 35   46014.02        85047.44        205517.64
# 44   22177.74       154806.14         28334.72
# 32   63408.86       129219.61         46085.25
# 34   46426.07       157693.92        210797.67

# %%
y_train
# Out:
# 3     182901.99
# 26    105733.54
# 20    118474.03
# 5     156991.12
# 22    110352.25
# 29    101004.64
# 23    108733.99
# 4     166187.94
# 42     71498.49
# 36     90708.19
# 30     99937.59
# 10    146121.95
# 21    111313.02
# 31     97483.56
# 16    126992.93
# 24    108552.04
# 39     81005.76
# 0     192261.83
# 27    105008.31
# 38     81229.06
# 25    107404.34
# 45     64926.08
# 46     49490.75
# 12    141585.52
# 41     77798.83
# 14    132602.65
# 49     14681.40
# 15    129917.04
# 1     191792.06
# 8     152211.77
# 7     155752.60
# 37     89949.14
# 2     191050.39
# 47     42559.73
# 48     35673.41
# Name: Profit, dtype: float64

# %%
y_test
# Out:
# 6     156122.51
# 43     69758.98
# 9     149759.96
# 40     78239.91
# 28    103282.38
# 18    124266.90
# 11    144259.40
# 33     96778.92
# 13    134307.35
# 17    125370.37
# 19    122776.86
# 35     96479.51
# 44     65200.33
# 32     97427.84
# 34     96712.80
# Name: Profit, dtype: float64

# %%
clf.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predicted = clf.predict(X_test)
y_predicted
# Out:
# array([155868.33749154,  57336.99036746, 154881.54403836,  73320.66972199,
#         98428.47646054, 128742.93020167, 135433.60024093,  97149.86812812,
#        126416.90080531, 129165.28825465, 112110.44950958,  90037.36583044,
#         61149.9602894 ,  96321.79680227,  87053.23435746])

# %%
y_test
# Out:
# 6     156122.51
# 43     69758.98
# 9     149759.96
# 40     78239.91
# 28    103282.38
# 18    124266.90
# 11    144259.40
# 33     96778.92
# 13    134307.35
# 17    125370.37
# 19    122776.86
# 35     96479.51
# 44     65200.33
# 32     97427.84
# 34     96712.80
# Name: Profit, dtype: float64

# %%
clf.score(X_test,y_test)
# Out:
# 0.9414971478412821

# %%
from sklearn.externals import joblib 
joblib.dump(clf, 'startups.pkl')
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# ['startups.pkl']

# %%
import pickle
pickle.dump(clf, open('startups.pkl','wb'))
model = pickle.load(open('startups.pkl','rb'))
print(model.predict([[1556.98,4325.76,8675.87]]))
# Out:
# [51053.1881722]

# %%
column = list(df.columns)
column
# Out:
# ['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit']

# %%
df.to_json('column.json')
